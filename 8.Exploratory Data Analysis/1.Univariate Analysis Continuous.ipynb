# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('CSV/iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
x_axis=df.index
y_axis=df['petal.length']

# %%
#scatterplot
sns.scatterplot(x=x_axis,y=y_axis,hue=df['variety'])
# Out:
# <AxesSubplot:ylabel='petal.length'>

# %%
#stripplot
sns.stripplot(x=df['variety'],y=df['petal.length'])
# Out:
# <AxesSubplot:xlabel='variety', ylabel='petal.length'>

# %%
#distribution plot
sns.distplot(df['petal.length'])
# sns.histplot(df['petal.length'])
# Out:
# c:\Users\Mihir\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal.length', ylabel='Density'>

# %%
#histogram
plt.hist(df['petal.length'],width=0.5)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#box plot
sns.boxplot(x=df['petal.length'])
# Out:
# <AxesSubplot:xlabel='petal.length'>
