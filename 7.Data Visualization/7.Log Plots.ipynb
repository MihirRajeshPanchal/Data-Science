# %%
import matplotlib.pyplot as plt

# %%
x_axis=[i for i in range(1,11)]
y_axis=[i**3 for i in range(1,11)]

# %%
#legend
plt.title("Two Plots in one graph")
plt.xlabel("Numbers")
plt.ylabel("Cubes")
plt.legend(["Cube"])
plt.yscale("log")
plt.plot(x_axis,y_axis)
