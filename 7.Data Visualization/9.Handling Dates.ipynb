# %%
import matplotlib.pyplot as plt

# %%
dates=['2018-04-07','2020-05-04','1990-05-20','1956-12-12','2021-08-07','2018-04-07','2010-05-04','1950-05-20','1936-12-12','2021-04-07']
values=[1,2,3,4,5,6,7,9,10,8]
plt.plot(dates,values)

# %%
plt.xticks(rotation=90)
plt.plot(dates,values)
